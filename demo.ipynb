# %% [markdown]
# # 1. Video Processing

# %%
# '--input', type=str, default='', help='path to an mp4 video or a folder with mp4 videos'
# '--output', type=str, default='output/', help='path to output'
# '--time_interval', type=float, default=5.0, help='path to output'
# '--min_face_size', type=int, default=200, help='the minimum face size for detection (width * height)'
# '--min_face_w', type=int, default=0, help='the minimum face width for detection'
# '--min_face_h', type=int, default=0, help='the minimum face height for detection'
# '--face_detect_threshold', type=float, default=0.5, help='the confidence threshold for face detection'
# '--worksheet', type=str, default='', help='a csv file with two columns: video_name, frame_number to indicate which frames to process (the frame number is senstive to the time interval set, and the first line should be kept for headers)'
# '--skip_processed', action='store_true', help='Skip videos that can be found in the same output path'

! python3 src/process_video.py --input 'demo.mp4' --output 'output/' --time_interval 0.5 --min_face_size 126 --min_face_h 126 --face_detect_threshold 0.5 --worksheet 'demo-worksheet.csv'

# %% [markdown]
# # 2. Image Folder Processing

# %%
#'--input', type=str, default='', help='path to a folder with images'
# '--output', type=str, default='output/', help='path to output'
# '--min_face_size', type=int, default=200, help='the minimum face size for detection (width * height)'
# '--min_face_w', type=int, default=0, help='the minimum face width for detection'
# '--min_face_h', type=int, default=0, help='the minimum face height for detection'
# '--face_detect_threshold', type=float, default=0.5, help='the confidence threshold for face detection'
# '--skip_processed', action='store_true', help='Skip an image folder that can be found in the same output path'

# The command below will process all images in the folder 'img_demo/' under this project and save the results in 'output/'

! python3 src/process_images.py --input 'img_demo/' --output 'output/' --min_face_size 64 --min_face_h 64 --face_detect_threshold 0.5

# %% [markdown]
# # 3. Regenerate TSNE Clusters
#
# The cell below demonstrates the command for forcing the program to regenerate TSNE results of a video (will be saved as "tsne.csv" under the result folder).
#
# This file will be generated by default when processing a video or an image folder.

# %%
# '--path', type=str, default='', help='the path to the result folder of a video'

! python3 src/tsne.py --path 'output/demo'
